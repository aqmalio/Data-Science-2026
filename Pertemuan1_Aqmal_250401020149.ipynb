# %% [markdown]
# <a href="https://colab.research.google.com/github/aqmalio/Data-Science-2026/blob/main/Pertemuan1_Aqmal_250401020149.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Nama: Aqmal
# * Nim: 250401020149
# * Kelas: IF405

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
# SEL 2: Variabel & tipe data
nama = "Aqmal"
angkatan = 2025
print(f"Halo, {nama} angkatan {angkatan}!")
# Out:
# Halo, Aqmal angkatan 2025!

# %%
# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. GitHub

# %%
# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Aqmal","Informatika",2025))
# Out:
# Aqmal | Informatika | 2025

# %% [markdown]
# ### Kesimpulan
#
# **Apa yang dipelajari:**
# * Dasar-dasar penggunaan Google Colab dan sintaksis Python.
# * Penggunaan variabel, tipe data, struktur data `list`, dan perulangan `for`.
# * Pendefinisian dan pemanggilan fungsi sederhana di Python.
#
# **Temuan Utama:**
# * Lingkungan Notebook mempermudah eksekusi kode baris demi baris secara interaktif.
#
# **Keterbatasan & Pertanyaan:**
# * Bagaimana cara menangani dataset yang besar secara efisien di dalam Colab?
